# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns # data visualization library  
import os
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics  # compute classification accuracy for the logistic regression model
from sklearn.neighbors import KNeighborsClassifier
np.random.seed(3)
import csv
from sklearn.model_selection import KFold

# %%
data = pd.read_csv('singer_distinguish.csv')

# %%
col = data.columns 
print(col)
# Out:
# Index(['Unnamed: 0', 'chroma_stft', 'rms', 'spec_cent', 'spec_bw', 'rolloff',
#        'zcr', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5', 'mfcc6', 'mfcc7',
#        'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12', 'mfcc13', 'mfcc14',
#        'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19', 'mfcc20', 'singer'],
#       dtype='object')

# %%
data["chroma_stft"].value_counts()
# Out:
# 0.318618    2
# 0.268777    2
# 0.352290    2
# 0.310404    1
# 0.334496    1
#            ..
# 0.356762    1
# 0.356753    1
# 0.228275    1
# 0.390284    1
# 0.375680    1
# Name: chroma_stft, Length: 807, dtype: int64

# %%
sns.set(style='white', color_codes=True)
sns.boxplot(x="chroma_stft", y="singer", data=data)
# Out:
# <AxesSubplot:xlabel='chroma_stft', ylabel='singer'>

# %%
data["rms"].value_counts()
sns.set(style='white', color_codes=True)
sns.boxplot(x="rms", y="singer", data=data)
# Out:
# <AxesSubplot:xlabel='rms', ylabel='singer'>

# %%
data["spec_cent"].value_counts()
sns.set(style='white', color_codes=True)
sns.boxplot(x="spec_cent", y="singer", data=data)
# Out:
# <AxesSubplot:xlabel='spec_cent', ylabel='singer'>

# %%
data["spec_bw"].value_counts()
sns.set(style='white', color_codes=True)
sns.boxplot(x="spec_bw", y="singer", data=data)
# Out:
# <AxesSubplot:xlabel='spec_bw', ylabel='singer'>

# %%
data["rolloff"].value_counts()
sns.set(style='white', color_codes=True)
sns.boxplot(x="rolloff", y="singer", data=data)
# Out:
# <AxesSubplot:xlabel='rolloff', ylabel='singer'>

# %%
data["zcr"].value_counts()
sns.set(style='white', color_codes=True)
sns.boxplot(x="zcr", y="singer", data=data)
# Out:
# <AxesSubplot:xlabel='zcr', ylabel='singer'>
